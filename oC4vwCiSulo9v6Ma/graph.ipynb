# %%
# Преамбула
# %matplotlib inline

import os
import matplotlib.pyplot as plt
import numpy as np

def save(name='', fmt='png'):
    pwd = os.getcwd()
    iPath = './pictures/{}'.format(fmt)
    if not os.path.exists(iPath):
        os.mkdir(iPath)
    os.chdir(iPath)
    plt.savefig('{}.{}'.format(name, fmt), fmt='png')
    os.chdir(pwd)
    #plt.close()

# %%
# Пример 2.1 

import matplotlib.pyplot as plt
import glob

# %%
fig = plt.figure()
# Добавление на рисунок прямоугольной (по умолчанию) области рисования
scatter1 = plt.scatter([0.0, 10], [1.0, 123])
print('Scatter: ', type(scatter1))



grid1 = plt.grid(True)   # линии вспомогательной сетки

# save(name='pic_2_1', fmt='pdf')
# save(name='pic_2_1', fmt='png')

plt.show()
# Out:
# Scatter:  <class 'matplotlib.collections.PathCollection'>

# %%
ls
# Out:
# a-sw-sw-c.arguments.process-args-1.csv
# a-sw-sw-c.arguments.process-args-3.csv
# a-sw-sw-c.basic-io.base7-1.csv
# a-sw-sw-c.basic-io.char-summ-2.csv
# a-sw-sw-c.basic-io.max-prod-4.csv
# a-sw-sw-c.basic-io.mul-table-1.csv
# a-sw-sw-c.basic-io.span-seq-1.csv
# a-sw-sw-c.basic-io.span-seq-2.csv
# a-sw-sw-c.data-structures.move-to-front-1.csv
# a-sw-sw-c.data-structures.reverse-list-1.csv
# a-sw-sw-c.data-structures.tree-1.csv
# a-sw-sw-c.floats.fixed-mul-1.csv
# a-sw-sw-c.floats.float-split-1.csv
# a-sw-sw-c.floats.fpclass-1.csv
# a-sw-sw-c.floats.fpmulf-1.csv
# a-sw-sw-c.floats.uint-fit-1.csv
# a-sw-sw-c.ints.addmod-1.csv
# a-sw-sw-c.ints.betole-1.csv
# a-sw-sw-c.ints.extract-1.csv
# a-sw-sw-c.ints.from-sym3-1.csv
# a-sw-sw-c.ints.poliz-sets-1.csv
# a-sw-sw-c.ints.satsum-1.csv
# a-sw-sw-c.ints.satsum-2.csv
# a-sw-sw-c.ints.simple-set-1.csv
# a-sw-sw-c.ints.simple-set-2.csv
# a-sw-sw-c.ints.to-sym3-1.csv
# a-sw-sw-c.ints.twos-compl-table-1.csv
# a-sw-sw-c.strings.common-dir-1.csv
# a-sw-sw-c.strings.common-dir-2.csv
# a-sw-sw-c.strings.getline2-1.csv
# a-sw-sw-c.strings.mystrcmp-3.csv
# a-sw-sw-c.strings.mystrdigcmp-1.csv
# a-sw-sw-c.strings.mystrspccmp-1.csv
# a-sw-sw-c.strings.normalize-path-1.csv
# a-sw-sw-c.texts.longest-word-utf-8-1.csv
# a-sw-sw-c.texts.max-int-min-double-2.csv
# a-sw-sw-c.texts.wchar-stats-1.csv
# a-sw-sw-ints.bitcount-2.csv
# c.arguments.process-args-1/
# c.arguments.process-args-1.csv
# c.arguments.process-args-1.html
# c.arguments.process-args-1_l.html
# c.arguments.process-args-3/
# c.arguments.process-args-3.csv
# c.arguments.process-args-3.html
# c.arguments.process-args-3_l.html
# c.basic-io.base7-1/
# c.basic-io.base7-1.csv
# c.basic-io.base7-1.html
# c.basic-io.base7-1_l.html
# c.basic-io.char-summ-2/
# c.basic-io.char-summ-2.csv
# c.basic-io.char-summ-2.html
# c.basic-io.char-summ-2_l.html
# c.basic-io.max-prod-4/
# c.basic-io.max-prod-4.csv
# c.basic-io.max-prod-4.html
# c.basic-io.max-prod-4_l.html
# c.basic-io.mul-table-1/
# c.basic-io.mul-table-1.csv
# c.basic-io.mul-table-1.html
# c.basic-io.mul-table-1_l.html
# c.basic-io.span-seq-1/
# c.basic-io.span-seq-1.csv
# c.basic-io.span-seq-1.html
# c.basic-io.span-seq-1_l.html
# c.basic-io.span-seq-2/
# c.basic-io.span-seq-2.csv
# c.basic-io.span-seq-2.html
# c.basic-io.span-seq-2_l.html
# c.data-structures.move-to-front-1/
# c.data-structures.move-to-front-1.csv
# c.data-structures.move-to-front-1.html
# c.data-structures.move-to-front-1_l.html
# c.data-structures.reverse-list-1/
# c.data-structures.reverse-list-1.csv
# c.data-structures.reverse-list-1.html
# c.data-structures.reverse-list-1_l.html
# c.data-structures.tree-1/
# c.data-structures.tree-1.csv
# c.data-structures.tree-1.html
# c.data-structures.tree-1_l.html
# c.floats.fixed-mul-1/
# c.floats.fixed-mul-1.csv
# c.floats.fixed-mul-1.html
# c.floats.fixed-mul-1_l.html
# c.floats.float-split-1/
# c.floats.float-split-1.csv
# c.floats.float-split-1.html
# c.floats.float-split-1_l.html
# c.floats.fpclass-1/
# c.floats.fpclass-1.csv
# c.floats.fpclass-1.html
# c.floats.fpclass-1_l.html
# c.floats.fpmulf-1/
# c.floats.fpmulf-1.csv
# c.floats.fpmulf-1.html
# c.floats.fpmulf-1_l.html
# c.floats.uint-fit-1/
# c.floats.uint-fit-1.csv
# c.floats.uint-fit-1.html
# c.floats.uint-fit-1_l.html
# c.ints.addmod-1/
# c.ints.addmod-1.csv
# c.ints.addmod-1.html
# c.ints.addmod-1_l.html
# c.ints.betole-1/
# c.ints.betole-1.csv
# c.ints.betole-1.html
# c.ints.betole-1_l.html
# c.ints.extract-1/
# c.ints.extract-1.csv
# c.ints.extract-1.html
# c.ints.extract-1_l.html
# c.ints.from-sym3-1/
# c.ints.from-sym3-1.csv
# c.ints.from-sym3-1.html
# c.ints.from-sym3-1_l.html
# c.ints.poliz-sets-1/
# c.ints.poliz-sets-1.csv
# c.ints.poliz-sets-1.html
# c.ints.poliz-sets-1_l.html
# c.ints.satsum-1/
# c.ints.satsum-1.csv
# c.ints.satsum-1.html
# c.ints.satsum-1_l.html
# c.ints.satsum-2/
# c.ints.satsum-2.csv
# c.ints.satsum-2.html
# c.ints.satsum-2_l.html
# c.ints.simple-set-1/
# c.ints.simple-set-1.csv
# c.ints.simple-set-1.html
# c.ints.simple-set-1_l.html
# c.ints.simple-set-2/
# c.ints.simple-set-2.csv
# c.ints.simple-set-2.html
# c.ints.simple-set-2_l.html
# c.ints.to-sym3-1/
# c.ints.to-sym3-1.csv
# c.ints.to-sym3-1.html
# c.ints.to-sym3-1_l.html
# c.ints.twos-compl-table-1/
# c.ints.twos-compl-table-1.csv
# c.ints.twos-compl-table-1.html
# c.ints.twos-compl-table-1_l.html
# c.strings.common-dir-1/
# c.strings.common-dir-1.csv
# c.strings.common-dir-1.html
# c.strings.common-dir-1_l.html
# c.strings.common-dir-2/
# c.strings.common-dir-2.csv
# c.strings.common-dir-2.html
# c.strings.common-dir-2_l.html
# c.strings.getline2-1/
# c.strings.getline2-1.csv
# c.strings.getline2-1.html
# c.strings.getline2-1_l.html
# c.strings.mystrcmp-3/
# c.strings.mystrcmp-3.csv
# c.strings.mystrcmp-3.html
# c.strings.mystrcmp-3_l.html
# c.strings.mystrdigcmp-1/
# c.strings.mystrdigcmp-1.csv
# c.strings.mystrdigcmp-1.html
# c.strings.mystrdigcmp-1_l.html
# c.strings.mystrspccmp-1/
# c.strings.mystrspccmp-1.csv
# c.strings.mystrspccmp-1.html
# c.strings.mystrspccmp-1_l.html
# c.strings.normalize-path-1/
# c.strings.normalize-path-1.csv
# c.strings.normalize-path-1.html
# c.strings.normalize-path-1_l.html
# c.texts.longest-word-utf-8-1/
# c.texts.longest-word-utf-8-1.csv
# c.texts.longest-word-utf-8-1.html
# c.texts.longest-word-utf-8-1_l.html
# c.texts.max-int-min-double-2/
# c.texts.max-int-min-double-2.csv
# c.texts.max-int-min-double-2.html
# c.texts.max-int-min-double-2_l.html
# c.texts.wchar-stats-1/
# c.texts.wchar-stats-1.csv
# c.texts.wchar-stats-1.html
# c.texts.wchar-stats-1_l.html
# graph.ipynb
# index.html
# ints.bitcount-2/
# ints.bitcount-2.csv
# ints.bitcount-2.html
# ints.bitcount-2_l.html
# pictures/
# SmithWatermanSmilarities.zip
# sw-c.arguments.process-args-1.csv
# sw-c.arguments.process-args-3.csv
# sw-c.basic-io.base7-1.csv
# sw-c.basic-io.char-summ-2.csv
# sw-c.basic-io.max-prod-4.csv
# sw-c.basic-io.mul-table-1.csv
# sw-c.basic-io.span-seq-1.csv
# sw-c.basic-io.span-seq-2.csv
# sw-c.data-structures.move-to-front-1.csv
# sw-c.data-structures.reverse-list-1.csv
# sw-c.data-structures.tree-1.csv
# sw-c.floats.fixed-mul-1.csv
# sw-c.floats.float-split-1.csv
# sw-c.floats.fpclass-1.csv
# sw-c.floats.fpmulf-1.csv
# sw-c.floats.uint-fit-1.csv
# sw-c.ints.addmod-1.csv
# sw-c.ints.betole-1.csv
# sw-c.ints.extract-1.csv
# sw-c.ints.from-sym3-1.csv
# sw-c.ints.poliz-sets-1.csv
# sw-c.ints.satsum-1.csv
# sw-c.ints.satsum-2.csv
# sw-c.ints.simple-set-1.csv
# sw-c.ints.simple-set-2.csv
# sw-c.ints.to-sym3-1.csv
# sw-c.ints.twos-compl-table-1.csv
# sw-c.strings.common-dir-1.csv
# sw-c.strings.common-dir-2.csv
# sw-c.strings.getline2-1.csv
# sw-c.strings.mystrcmp-3.csv
# sw-c.strings.mystrdigcmp-1.csv
# sw-c.strings.mystrspccmp-1.csv
# sw-c.strings.normalize-path-1.csv
# sw-c.texts.longest-word-utf-8-1.csv
# sw-c.texts.max-int-min-double-2.csv
# sw-c.texts.wchar-stats-1.csv
# sw-ints.bitcount-2.csv

# %%
files = glob.glob("a-sw-*.csv")

# %%
import pandas as pd

# %%
for filename in files:
    file = pd.read_csv(filename, sep=';', header=None, names=['folder', 'name1', 'name2', 'dist', 'sim'])
    fig = plt.figure()
    scatter1 = plt.scatter(file.dist, file.sim)
    grid1 = plt.grid(True)   # линии вспомогательной сетки
    save(name=file.folder[0], fmt='png')
# Out:
# /home/nokados/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
len(files)
# Out:
# 38
